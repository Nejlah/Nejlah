# %% [markdown]
# <a href="https://colab.research.google.com/github/Nejlah/Nejlah/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
brg = []

user = 0

while user != 7 :
  print('''
  1. menambahkan
  2. menghapus
  3. mengedit
  4. menampilkan
  5. mencari barang
  6. mencari index
  7. keluar
  ''')

  user = int(input("masukkan operator anda : "))

  if user == 1 :
    while True :
      a = input("masukkan barang : ")
      brg.append(a)

      print("barang sekarang : ", brg)

      stop = input("ketik y untuk berhenti : ")
      if stop == 'y' :
        break

  elif user == 2 :
    while True :
      a = int(input("masukkan index yang akan di hapus : "))

      if a >= len(brg) :
        print("index tidak ditemukan ")

      else:
        print(brg.pop(a))

        print("barang sekarang : ", brg)

        stop = input("ketik y untuk berhenti : ")
        if stop == 'y' :
          break

  elif user == 3 :
    while True :
      b = int(input("masukkan index yang akan diganti : "))

      if b > len(brg) :
        print("index tidak ditemukan ")
      else:
        brg[b] = input("masukkan barang pengganti : ")

        print("barang sekarang : ", brg)

        stop = input("ketik y untuk berhenti : ")
        if stop == 'y' :
          break

  elif user == 4 :
    for i in range(len(brg)) :
      print("barang sekarang ", brg[i])

  elif user == 5 :
    cari = input("masukkan barang yang dicari : ")

    if cari in brg :
      print("barang ditemukan")

    else:
      print("barang tidak ditemukan ")

  elif user == 6 :
    cari1 = input("masukkan barang yang dicari : ")

    if cari1 in brg :
      print(f"{cari1 } ditemukan pada index ke- {brg.index (cari1)}")
    else:
      print("barang tidak ditemukan")

    elif user > 7 :
      print("periksa kembali inputan anda ")
# Out:
#   1. menambahkan
#   2. menghapus
#   3. mengedit
#   4. menampilkan
#   5. mencari barang
#   6. mencari index
#   7. keluar
#
# masukkan operator anda : 1
# masukkan barang : kursi
# barang sekarang :  ['kursi']
# ketik y untuk berhenti : h
# masukkan barang : meja
# barang sekarang :  ['kursi', 'meja']
# ketik y untuk berhenti : i
# masukkan barang : lemari
# barang sekarang :  ['kursi', 'meja', 'lemari']
# ketik y untuk berhenti : r
# masukkan barang : jendela
# barang sekarang :  ['kursi', 'meja', 'lemari', 'jendela']
# ketik y untuk berhenti : y
#
#   1. menambahkan
#   2. menghapus
#   3. mengedit
#   4. menampilkan
#   5. mencari barang
#   6. mencari index
#   7. keluar
#
# masukkan operator anda : 6
# masukkan barang yang dicari : lemari
# lemari ditemukan pada index ke- 2
#
#   1. menambahkan
#   2. menghapus
#   3. mengedit
#   4. menampilkan
#   5. mencari barang
#   6. mencari index
#   7. keluar
#
# masukkan operator anda : 7
